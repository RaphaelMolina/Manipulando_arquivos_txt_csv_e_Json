# %% [markdown]
# <a href="https://colab.research.google.com/github/RaphaelMolina/Manipulando_arquivos_txt_csv_e_Json/blob/main/Manipulando_arquivos_txt%2C_csv_e_Json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar Bibliotecas

# %%
import csv
import pandas as pd

# %% [markdown]
# # Abrir um arquivo de texto

# %% [markdown]
# Retirado da página:
# https://pt.wikipedia.org/wiki/Machado_de_Assis

# %%
arquivo = open('Machado_de_Assis.txt', 'r')

# %% [markdown]
# # Ler linhas, fechar arquivo e mostrar conteudo

# %%
conteudo = arquivo.readlines()
arquivo.close()

# %%
print(conteudo)
print('-----')
for linha in conteudo:
  print(linha)
# Out:
# ['Perfil de Machado de Assis, 1904.\n', 'Arquivo Nacional.\n', 'Nome completo\tJoaquim Maria Machado de Assis\n', 'Nascimento\t21 de junho de 1839\n', 'Rio de Janeiro, MN\n', 'Império do Brasil\n', 'Morte\t29 de setembro de 1908 (69 anos)\n', 'Rio de Janeiro, DF\n', 'Estados Unidos do Brasil\n', 'Nacionalidade\tbrasileiro\n', 'Cônjuge\tCarolina Augusta Xavier de Novais (1869–1904)\n', 'Ocupação\tEscritor, jornalista, contista, cronista, dramaturgo e poeta\n', 'Movimento literário\tRomantismo/Realismo\n', 'Magnum opus\tEntre os críticos e o público, destacam-se Memórias Póstumas de Brás Cubas e Dom Casmurro. A crítica considera que suas melhores obras são as da Trilogia Realista.[1]\n', 'Joaquim Maria Machado de Assis (Rio de Janeiro, 21 de junho de 1839 – Rio de Janeiro, 29 de setembro de 1908) foi um escritor brasileiro, considerado por muitos críticos, estudiosos, escritores e leitores um dos maiores senão o maior nome da literatura do Brasil.[2][3][4][5][6] Escreveu em praticament
# ...

# %% [markdown]
# # Alterar em todo o texto a palavra "Rio de Janeiro" por "Ribeirão Preto"

# %%
x = ''
for linha in conteudo:
  if linha != '':
    x += linha

print(x)
x = x.replace('Rio de Janeiro', 'Ribeirão Preto')
print('----------')
print(x)
# Out:
# Perfil de Machado de Assis, 1904.
# Arquivo Nacional.
# Nome completo	Joaquim Maria Machado de Assis
# Nascimento	21 de junho de 1839
# Rio de Janeiro, MN
# Império do Brasil
# Morte	29 de setembro de 1908 (69 anos)
# Rio de Janeiro, DF
# Estados Unidos do Brasil
# Nacionalidade	brasileiro
# Cônjuge	Carolina Augusta Xavier de Novais (1869–1904)
# Ocupação	Escritor, jornalista, contista, cronista, dramaturgo e poeta
# Movimento literário	Romantismo/Realismo
# Magnum opus	Entre os críticos e o público, destacam-se Memórias Póstumas de Brás Cubas e Dom Casmurro. A crítica considera que suas melhores obras são as da Trilogia Realista.[1]
# ...

# %% [markdown]
# # Gravar (Gerar um novo arquivo)

# %%
arquivo_novo = open('Machado_de_Assis_2.txt', 'w')
arquivo_novo.writelines(x)
arquivo_novo.close()

# %% [markdown]
# # Trabalhando com arquivos CSV

# %%
import csv
with open('Tesla.csv', 'r') as f:
  leitor = csv.reader(f, delimiter=',')
  for linha in leitor:
    data = linha[0]
    fechamento = linha[4]
    volume = linha[5]
    print('Data: ', data, '--Fechamento: ', fechamento, '--Volume: ', volume)
# Out:
# Data:  Date --Fechamento:  Close --Volume:  Volume
# Data:  6/29/2010 --Fechamento:  23.889999 --Volume:  18766300
# Data:  6/30/2010 --Fechamento:  23.83 --Volume:  17187100
# Data:  7/1/2010 --Fechamento:  21.959999 --Volume:  8218800
# Data:  7/2/2010 --Fechamento:  19.200001 --Volume:  5139800
# Data:  7/6/2010 --Fechamento:  16.110001 --Volume:  6866900
# Data:  7/7/2010 --Fechamento:  15.8 --Volume:  6921700
# Data:  7/8/2010 --Fechamento:  17.459999 --Volume:  7711400
# Data:  7/9/2010 --Fechamento:  17.4 --Volume:  4050600
# Data:  7/12/2010 --Fechamento:  17.049999 --Volume:  2202500
# Data:  7/13/2010 --Fechamento:  18.139999 --Volume:  2680100
# Data:  7/14/2010 --Fechamento:  19.84 --Volume:  4195200
# Data:  7/15/2010 --Fechamento:  19.889999 --Volume:  3739800
# Data:  7/16/2010 --Fechamento:  20.639999 --Volume:  2621300
# Data:  7/19/2010 --Fechamento:  21.91 --Volume:  2486500
# Data:  7/20/2010 --Fechamento:  20.299999 --Volume:  1825300
# ...

# %% [markdown]
# # Trabalhando com arquivo CSV usando o Pandas

# %%
arquivo_p = 'https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv'
dados = pd.read_csv(arquivo_p)
dados
# Out:
#      tourney_id  tourney_name  ... loser_rank  loser_rank_points
# 0     2021-0499  Delray Beach  ...      119.0              566.0
# 1     2021-0499  Delray Beach  ...      789.0               22.0
# 2     2021-0499  Delray Beach  ...       74.0              877.0
# 3     2021-0499  Delray Beach  ...      101.0              733.0
# 4     2021-0499  Delray Beach  ...      293.0              171.0
# ...         ...           ...  ...        ...                ...
# 2423  2021-7485       Antwerp  ...       74.0              912.0
# 2424  2021-7485       Antwerp  ...       72.0              930.0
# 2425  2021-7485       Antwerp  ...       26.0             2071.0
# 2426  2021-7485       Antwerp  ...       47.0             1270.0
# 2427  2021-7485       Antwerp  ...       48.0             1217.0
#
# [2428 rows x 49 columns]

# %% [markdown]
# # Vamos plotar uma informação

# %%
dados.winner_hand.value_counts().sort_values().plot(kind = 'barh')

# %% [markdown]
# # Abrir o arquivo da Tesla usando o Pandas, determinando nome das colunas e puxando apenas 4 linhas

# %%
arquivo_t = 'Tesla.csv'
dados = pd.read_csv(arquivo_t, skiprows=1, names=['Data', 'Abertura', 'Max', 'Min', 'Fechamento', 'Volume', 'Ajustado'],nrows=4)
dados
# Out:
#         Data   Abertura    Max        Min  Fechamento    Volume   Ajustado
# 0  6/29/2010  19.000000  25.00  17.540001   23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999   23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000   21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999   19.200001   5139800  19.200001

# %% [markdown]
# # Trabalhar com arquivos Json, buscando dados da API (https://randomuser.me/api) que gera como resultado arquivos JSON. Essa é uma API para teste (gera dados de usuários aleatórios)

# %%
import json
import requests

# %%
resposta = requests.get('https://randomuser.me/api')
dados = json.loads(resposta.text)
dados
# Out:
# {'info': {'page': 1,
#   'results': 1,
#   'seed': 'd8a80b8866afd8fc',
#   'version': '1.3'},
#  'results': [{'cell': '(544)-752-7754',
#    'dob': {'age': 60, 'date': '1961-07-16T09:09:46.917Z'},
#    'email': 'kubra.adivar@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'Iğdır',
#     'coordinates': {'latitude': '72.2382', 'longitude': '119.3276'},
#     'country': 'Turkey',
#     'postcode': 64548,
#     'state': 'Tekirdağ',
#     'street': {'name': 'Kushimoto Sk', 'number': 6566},
#     'timezone': {'description': 'Mid-Atlantic', 'offset': '-2:00'}},
#    'login': {'md5': '145afd00304cc4ca9c6277a99dedafca',
#     'password': 'zhuo',
#     'salt': 'hEg7dkH2',
#     'sha1': '32f6a87fbece6cb8e9d035a9db0ad4ada8b029da',
#     'sha256': '35d6e311f52cd2365cf5388e283a4671f2e382335489ae745016f1640a19d667',
#     'username': 'goldencat814',
#     'uuid': '8005a3fb-9171-4f12-8df5-2c4d542f746f'},
# ...

# %%
print(dados['results'][0]['name']['first'])
# Out:
# Kübra
